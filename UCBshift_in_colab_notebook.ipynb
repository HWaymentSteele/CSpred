# %% [markdown]
# <a href="https://colab.research.google.com/github/HWaymentSteele/CSpred/blob/main/UCBshift_in_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install packages and download UCBshift weights

# Install packages
# !pip install git+https://github.com/HWaymentSteele/CSpred.git hydride

# # Download and extract model weights
from huggingface_hub import snapshot_download
from cspred import predict_shifts
import os
import subprocess as sp

repo_id = "hkws/ucbshift_weights"
local_dir = "./ucbshift_weights"

if not os.path.exists(f'{local_dir}/CA_R0.sav'):
  os.makedirs(local_dir, exist_ok=True)
  snapshot_download(repo_id=repo_id, repo_type="model", local_dir=local_dir)
# Out:
# Collecting git+https://github.com/HWaymentSteele/CSpred.git
#   Cloning https://github.com/HWaymentSteele/CSpred.git to /tmp/pip-req-build-ik__nxbk
#   Running command git clone --filter=blob:none --quiet https://github.com/HWaymentSteele/CSpred.git /tmp/pip-req-build-ik__nxbk
#   Resolved https://github.com/HWaymentSteele/CSpred.git to commit 29c97659249b931a12ebb92e9a0132b799a97034
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting hydride
#   Downloading hydride-1.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from cspred==1.0.0) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from cspred==1.0.0) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from cspred==1.0.0) (1.6.1)
# Collecting biopython>=1.81 (from cspred==1.0.0)
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: joblib>=1.3 in /usr/local/lib/python3.12/dist-packages (from cspred==1.0.0) (1.5.3)
# Collecting biotite>=0.40 (from hydride)
#   Downloading biotite-1.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting biotraj<2.0,>=1.0 (from biotite>=0.40->hydride)
#   Downloading biotraj-1.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from biotite>=0.40->hydride) (1.1.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.12/dist-packages (from biotite>=0.40->hydride) (3.6.1)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from biotite>=0.40->hydride) (26.1)
# Requirement already satisfied: requests>=2.12 in /usr/local/lib/python3.12/dist-packages (from biotite>=0.40->hydride) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->cspred==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->cspred==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->cspred==1.0.0) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->cspred==1.0.0) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->cspred==1.0.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->cspred==1.0.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite>=0.40->hydride) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite>=0.40->hydride) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite>=0.40->hydride) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite>=0.40->hydride) (2026.4.22)
# Downloading hydride-1.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.4 MB/s eta 0:00:00
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 38.3 MB/s eta 0:00:00
# Downloading biotite-1.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 12.2 MB/s eta 0:00:00
# Downloading biotraj-1.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 38.1 MB/s eta 0:00:00
# Building wheels for collected packages: cspred
#   Building wheel for cspred (pyproject.toml) ... done
#   Created wheel for cspred: filename=cspred-1.0.0-py3-none-any.whl size=27677150 sha256=776c3f7e89f3e7f5c906b4e7bc2bd18353f6daadef6887d026a259f533d07151
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nnhhj93m/wheels/0a/67/7b/6164fcbf6965e742a6fea3dcbc113e4249fe63f0b8a5dbd2de
# Successfully built cspred
# Installing collected packages: biopython, biotraj, cspred, biotite, hydride
# Successfully installed biopython-1.87 biotite-1.6.0 biotraj-1.2.2 cspred-1.0.0 hydride-1.2.3
# Decompressing mTM-align database...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
protein='1UBQ'

#fetch protein
sp.run(["wget", f"https://files.rcsb.org/download/{protein}.pdb"], check=True)

#add hydrogens with hydride package
sp.run(["hydride", "-i", f"{protein}.pdb", "-o", f"{protein}_hyd.pdb"], check=True)

#to specify only doing subset of atoms, otherwise omit
import toolbox
toolbox.ATOMS = ['H','N']

#generate predictions
df = predict_shifts(f"{protein}_hyd.pdb", pH=7.0, TP=False)
# Out:
# Generating features ...
# Calculating UCBShift-X predictions for H ...
# Calculating UCBShift-X predictions for N ...

# %%
print(df.head())
# Out:
#    RESNUM RESNAME       H_X         N_X
# 0       1     MET  8.390947  119.873000
# 1       2     GLN  8.708531  123.372268
# 2       3     ILE  8.495669  118.658359
# 3       4     PHE  9.091323  119.015849
# 4       5     VAL  9.389333  123.241998
